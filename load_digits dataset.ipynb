# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
data= datasets.load_digits()

# %%
plt.subplot()
plt.imshow(data.images[0], plt.cm.gray_r)

# %%
image_and_libel= list(zip(data.images,data.target))
image_and_libel[0]
# Out:
# (array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#         [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#         [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#         [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#         [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#         [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#         [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#         [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]]),
#  0)

# %%
for i, (image, label) in enumerate(image_and_libel[:11]):
    plt.subplot(2,11,i+1)
    plt.imshow(image, plt.cm.gray_r)
    plt.title(label)
